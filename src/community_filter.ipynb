    """pass in a dictionary of 
    number of unique tweets -> 
    total unique tweets tweeted by communities having that number of unique tweets"""
    tweet_count_2_comms = {}
    for k in d:
        num_communities = d[k]/k
        tweet_count_2_comms[k] = num_communities
    return tweet_count_2_comms

count_maps = [
    phase1_community_tweet_counts,
    phase2_community_tweet_counts,
    phase3_community_tweet_counts,
    phase4_community_tweet_counts,
    phase5_community_tweet_counts,
    phase6_community_tweet_counts,
]

count_2_comms_map = {}
for i, count_map in enumerate(count_maps):
    period = i + 1
    count_2_comms_map[period] = number_of_communities_per_tweet_count(count_map)

# %%
period_2_num_comms = {k: int(sum(count_2_comms_map[k].values())) for k in count_2_comms_map}
period_2_num_comms
# Out:
# {1: 687, 2: 6508, 3: 7443, 4: 1919, 5: 77287, 6: 38819}

# %%
fig, ((ax1, ax2), (ax3, ax4), (ax5, ax6)) = plt.subplots(
    nrows=3, 
    ncols=2, 
    sharex=True, 
    sharey=True, 
    figsize=(6,8)
)
axes = [ax1, ax3, ax5, ax2, ax4, ax6]
periods = [i for i in range(1, 7)]
data = [count_2_comms_map[p] for p in periods]
thresholds = [25, 25, 25, 10, 20, 20]
max_num_communities = 54_740
for ax, count_map, period,threshold in zip(axes, data, periods, thresholds):
    ax.set_xscale("log")
    ax.set_yscale("log")
    ax.fill_between([0, max_num_communities], threshold, color="xkcd:light grey")
    ax.scatter(count_map.values(), count_map.keys(),  s=4, c='blue')
    ax.hlines(threshold, xmin=0, xmax=max_num_communities, linestyles="dashed", label="inclusion threshold")
    if period in (3, 6):
        ax.set_xlabel("Number of communities")
    if period == 1:
        ax.set_title("2014/15", loc="center", fontweight="bold")
        ax.set_ylabel("Struggle", fontweight="bold")
        ax.legend()
    elif period == 2:
        ax.set_ylabel("Surge", fontweight="bold")
    elif period == 3:
        ax.set_ylabel("Consolidation", fontweight="bold")
    elif period == 4:
        ax.set_title("2020", loc="center", fontweight="bold")
        ax.legend()

# %%
def analyze_tweet_counts(threshold, count_map):
    """Returns Tuple[qty OTs included, qty OTs excluded]"""
    included, excluded = 0, 0
    for ot in count_map:
        if ot < threshold:
            excluded += count_map[ot]
        else:
            included += count_map[ot]
    return included, excluded

def analyze_num_communities(threshold, num_comms_map):
    """Returns Tuple[qty communities included, qty communities excluded]"""
    included, excluded = 0, 0
    for ot in count_map:
        if ot < threshold:
            excluded += count_map[ot]
        else:
            included += count_map[ot]
    return included, excluded    

included_OTs, excluded_OTs = 0, 0
for i in range(6):
    included, excluded = analyze_tweet_counts(thresholds[i], count_maps[i])
    included_OTs += included
    excluded_OTs += excluded

included_comms, excluded_comms = 0, 0
for i in range(6):
    included, excluded = analyze_num_communities(thresholds[i], count_2_comms_map[i + 1])
    included_comms += included
    excluded_comms += excluded

print("OTs: included = ", included_OTs, "; excluded = ", excluded_OTs, "; total = ", included_OTs + excluded_OTs)
print("Comms: included = ", included_comms, "; excluded = ", excluded_comms, "; total = ", included_comms + excluded_comms)
# Out:
# OTs: included =  2429565 ; excluded =  236024 ; total =  2665589
# Comms: included =  3070.0 ; excluded =  229844.0 ; total =  232914.0

# %%
print(round(included_OTs / (included_OTs + excluded_OTs), 3), "OTs included")
print(round(excluded_comms / (included_comms + excluded_comms), 3), "communities excluded")
# Out:
# 0.911 OTs included
# 0.987 communities excluded
